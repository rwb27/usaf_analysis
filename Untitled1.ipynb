# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib qt
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-2-c9659eb8d496> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 get_ipython().magic(u'matplotlib qt')
#
# C:\local\software\anaconda\lib\site-packages\IPython\core\interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# C:\local\software\anaconda\lib\site-packages\IPython\core\interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# ...
